# %%
reset()
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==2*y
show(eqd)
desolve(eqd,y)
show(desolve(eqd,y,show_method=True))
# Out:
# diff(y(x), x) == 2*y(x)
# [_C*e^(2*x), 'linear']

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==2*x*(1+y^2)
show(eqd)
s=desolve(eqd,y)
show(s)
ans1=solve(s,y(x))
show(ans1)
ysol(x,_C)=ans1[0].rhs()
show(ysol)
g=plot(ysol(x,0),x,-10,10,detect_poles='True',ymin=-10,ymax=10)
for i in [1..3]:
    g=g+plot(ysol(x,i),x,-10,10,detect_poles='True',ymin=-10,ymax=10)
show(g)
# Out:
# diff(y(x), x) == 2*(y(x)^2 + 1)*x
# 1/2*arctan(y(x)) == 1/2*x^2 + _C
# [y(x) == tan(x^2 + 2*_C)]
# (x, _C) |--> tan(x^2 + 2*_C)
# Graphics object consisting of 253 graphics primitives

# %%
x=var('x')
y=function('y')(x)
eqd=(x^2-1)*diff(y,x)+2*x*y^2 == 0
show(eqd)
s=desolve(eqd,y)
show(s)
ans1=solve(s,y(x))
show(ans1)
sol(x,_C)=ans1[0].rhs()
show(sol)
g=plot(sol(x,0),x,1,10,detect_poles='True',ymin=-10,ymax=10)
for i in [1..3]:
    g=g+plot(sol(x,i),x,1,10,detect_poles='True',ymin=-10,ymax=10)
show(g)
# Out:
# 2*x*y(x)^2 + (x^2 - 1)*diff(y(x), x) == 0
# 1/2/y(x) == _C + 1/2*log(x + 1) + 1/2*log(x - 1)
# [y(x) == (1/(2*_C + log(x + 1) + log(x - 1)))]
# (x, _C) |--> 1/(2*_C + log(x + 1) + log(x - 1))
# Graphics object consisting of 7 graphics primitives

# %%
x=var('x')
y=function('y')(x)
eqd=2*x^2*diff(y,x)==x^2+y^2
show(eqd)
s=desolve(eqd,y)
show(s)
ans1=solve(s,y(x))
show(ans1)
sol1(x,_C)=ans1[1].rhs()
show(sol1)
g=plot(sol1(x,1),x,1,10,detect_poles='True',ymin=-10,ymax=10)
for i in [2..10]:
    g=g+plot(sol1(x,i),x,1,10,detect_poles='True',ymin=-10,ymax=10)
show(g)
# Out:
# 2*x^2*diff(y(x), x) == x^2 + y(x)^2
# _C*x == e^(2*x/(x - y(x)))
# [y(x) == (x*log(-1/sqrt(_C*x)) + x)/log(-1/sqrt(_C*x)), y(x) == (x*log(_C*x) - 2*x)/log(_C*x)]
# (x, _C) |--> (x*log(_C*x) - 2*x)/log(_C*x)
# Graphics object consisting of 10 graphics primitives

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==-(x+y)/y
show(eqd)
s=desolve(eqd,y)
show(s)
ans1=solve(s,y(x))
show(ans1)
yy=var('yy')
f(x,yy,_C)=s.substitute(y(x)==yy)
implicit_plot(f(x,yy,1),(x,-10,10),(yy,-10,10))
# Out:
# diff(y(x), x) == -(x + y(x))/y(x)
# _C*x == e^(-1/6*sqrt(3)*(sqrt(3)*log((x^2 + x*y(x) + y(x)^2)/x^2) - 2*arctan(1/3*sqrt(3)*(x + 2*y(x))/x)))
# []
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x,2)+y==sin(x)+cos(x)
show(eqd)
s=desolve(eqd,y)
show(s)
ans1=solve(x,y(x))
_K1,_K2=var('_K1,_K2')
sol1=s.substitute(_K1==1,_K2==2)
show(sol1)
plot(sol1,x,-2,2,detect_poles='True')
# Out:
# y(x) + diff(y(x), x, x) == cos(x) + sin(x)
# _K2*cos(x) - 1/2*(x - 1)*cos(x) + _K1*sin(x) + 1/2*x*sin(x)
# -1/2*(x - 1)*cos(x) + 1/2*x*sin(x) + 2*cos(x) + sin(x)
# Graphics object consisting of 2 graphics primitives

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x,2)-y==e^(2*x)
show(eqd)
s=desolve(eqd,y)
show(s)
ans1=solve(x,y(x))
_K1,_K2=var('_K1,_K2')
sol1=s.substitute(_K1==1,_K2==2)
show(sol1)
plot(sol1,x,-2,2,detect_poles='True')
# Out:
# -y(x) + diff(y(x), x, x) == e^(2*x)
# _K2*e^(-x) + _K1*e^x + 1/3*e^(2*x)
# 1/3*e^(2*x) + 2*e^(-x) + e^x
# Graphics object consisting of 2 graphics primitives

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x,2)-diff(y,x)==1/(1+e^x)
show(eqd)
s=desolve(eqd,y)
show(s)
ans1=solve(x,y(x))
_K1,_K2=var('_K1,_K2')
sol1=s.substitute(_K1==1,_K2==2)
show(sol1)
plot(sol1,x,-2,2,detect_poles='True')
# Out:
# -diff(y(x), x) + diff(y(x), x, x) == (1/(e^x + 1))
# _K1*e^x + e^x*log((e^x + 1)*e^(-x)) + _K2 - x + log(e^x + 1)
# e^x*log((e^x + 1)*e^(-x)) - x + e^x + log(e^x + 1) + 2
# Graphics object consisting of 2 graphics primitives

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==1+y^2
s=desolve(eqd,y,ics=[0,1])
show(s)
sol=solve(s,y(x))
show(sol)
ans1=sol[0].rhs()
plot(ans1,x,-10,10,detect_poles='True',ymin=-10,ymax=10)
# Out:
# arctan(y(x)) == 1/4*pi + x
# [y(x) == tan(1/4*pi + x)]
# Graphics object consisting of 8 graphics primitives

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==1/(1-x^2)*y+1+x
s=desolve(eqd,y,ics=[2,0])
show(s)
plot(s,x,1,3,detect_poles='True',ymin=-10,ymax=10)
# Out:
# 1/2*(sqrt(x^2 - 1)*sqrt(x + 1)*x - sqrt(x + 1)*(2*sqrt(3) - log(2*sqrt(3) + 4)) - sqrt(x + 1)*log(2*x + 2*sqrt(x^2 - 1)))/sqrt(x - 1)
# Graphics object consisting of 1 graphics primitive
