# %%
t=var('t')
x=function('x')(t)
y=function('y')(t)
eq1=diff(x,t)==x+4*y
eq2=diff(y,t)==x+y
syst=[eq1, eq2]
C1,C2=var('C1,C2')
sol=desolve_system(syst, [x, y], [0, C1, C2])
show(sol)
sol_x(t,C1,C2)=sol[0].rhs()
show(sol_x)
reprx=plot(sol_x(t, 1, 1), t, -4, 4, color='red')
sol_y(t,C1,C2)=sol[1].rhs()
show(sol_y)
repry=plot(sol_y(t, 1, 1), t, -4, 4, color='cyan')
show(reprx+repry)
# Out:
# [x(t) == 1/2*(C1 + 2*C2)*e^(3*t) + 1/2*(C1 - 2*C2)*e^(-t),
#  y(t) == 1/4*(C1 + 2*C2)*e^(3*t) - 1/4*(C1 - 2*C2)*e^(-t)]
# (t, C1, C2) |--> 1/2*(C1 + 2*C2)*e^(3*t) + 1/2*(C1 - 2*C2)*e^(-t)
# (t, C1, C2) |--> 1/4*(C1 + 2*C2)*e^(3*t) - 1/4*(C1 - 2*C2)*e^(-t)
# Graphics object consisting of 2 graphics primitives

# %%
t=var('t')
x=function('x')(t)
y=function('y')(t)
eq1=diff(x,t)==2*x-y
eq2=diff(y,t)==x+2*y
syst=[eq1, eq2]
C1,C2=var('C1,C2')
sol=desolve_system(syst, [x, y], [0, C1, C2])
show(sol)
sol_x(t,C1,C2)=sol[0].rhs()
show(sol_x)
reprx=plot(sol_x(t, 1, 1), t, -4, 4, color='yellow')
sol_y(t,C1,C2)=sol[1].rhs()
show(sol_y)
repry=plot(sol_y(t, 1, 1), t, -4, 4, color='cyan')
show(reprx+repry)
# Out:
# [x(t) == (C1*cos(t) - C2*sin(t))*e^(2*t),
#  y(t) == (C2*cos(t) + C1*sin(t))*e^(2*t)]
# (t, C1, C2) |--> (C1*cos(t) - C2*sin(t))*e^(2*t)
# (t, C1, C2) |--> (C2*cos(t) + C1*sin(t))*e^(2*t)
# Graphics object consisting of 2 graphics primitives

# %%
t=var('t')
x=function('x')(t)
y=function('y')(t)
z=function('z')(t)
eq1=diff(x,t)==x-y+z
eq2=diff(y,t)==x+y-z
eq3=diff(z,t)==-y+2*z
syst=[eq1, eq2, eq3]
C1,C2,C3=var('C1,C2,C3')
sol=desolve_system(syst, [x, y, z], [0, C1, C2, C3])
show(sol)
sol_x(t,C1,C2,C3)=sol[0].rhs()
show(sol_x)
reprx=plot(sol_x(t, 1, 2, -1), t, -4, 4, color='red',ymin=-10,ymax=10)
sol_y(t,C1,C2,C3)=sol[1].rhs()
show(sol_y)
repry=plot(sol_y(t, 1, 2, -1), t, -4, 4, color='cyan',ymin=-10,ymax=10)
sol_z(t,C1,C2,C3)=sol[2].rhs()
show(sol_z)
reprz=plot(sol_z(t, 1, 2, -1), t, -4, 4, color='blue',ymin=-10,ymax=10)
show(reprx+repry+reprz)
# Out:
# [x(t) == C1*t*e^t - C3*t*e^t - (C1 + C2 - 2*C3)*e^(2*t) + (2*C1 + C2 - 2*C3)*e^t,
#  y(t) == C1*t*e^t - C3*t*e^t + C2*e^t,
#  z(t) == C1*t*e^t - C3*t*e^t - (C1 + C2 - 2*C3)*e^(2*t) + (C1 + C2 - C3)*e^t]
# (t, C1, C2, C3) |--> C1*t*e^t - C3*t*e^t - (C1 + C2 - 2*C3)*e^(2*t) + (2*C1 + C2 - 2*C3)*e^t
# (t, C1, C2, C3) |--> C1*t*e^t - C3*t*e^t + C2*e^t
# (t, C1, C2, C3) |--> C1*t*e^t - C3*t*e^t - (C1 + C2 - 2*C3)*e^(2*t) + (C1 + C2 - C3)*e^t
# Graphics object consisting of 3 graphics primitives

# %%
t=var('t')
x=function('x')(t)
y=function('y')(t)
eq1=diff(x,t)==5*x+3*y+1
eq2=diff(y,t)==-6*x-4*y+e^(-t)
syst=[eq1, eq2]
C1,C2=var('C1,C2')
sol=desolve_system(syst, [x, y], [0, C1, C2])
show(sol)
sol_x(t,C1,C2)=sol[0].rhs()
show(sol_x)
reprx=plot(sol_x(t, 1, 1), t, -4, 4, color='yellow',ymin=-10,ymax=10)
sol_y(t,C1,C2)=sol[1].rhs()
show(sol_y)
repry=plot(sol_y(t, 1, 1), t, -4, 4, color='cyan',ymin=-10,ymax=10)
show(reprx+repry)
# Out:
# [x(t) == 1/3*(6*C1 + 3*C2 + 4)*e^(2*t) - 1/3*(3*C1 + 3*C2 - 2)*e^(-t) - t*e^(-t) - 2,
#  y(t) == -1/3*(6*C1 + 3*C2 + 4)*e^(2*t) + 1/3*(6*C1 + 6*C2 - 5)*e^(-t) + 2*t*e^(-t) + 3]
# (t, C1, C2) |--> 1/3*(6*C1 + 3*C2 + 4)*e^(2*t) - 1/3*(3*C1 + 3*C2 - 2)*e^(-t) - t*e^(-t) - 2
# (t, C1, C2) |--> -1/3*(6*C1 + 3*C2 + 4)*e^(2*t) + 1/3*(6*C1 + 6*C2 - 5)*e^(-t) + 2*t*e^(-t) + 3
# Graphics object consisting of 2 graphics primitives

# %%
t=var('t')
x=function('x')(t)
y=function('y')(t)
eq1=diff(x,t)==x+3*y+cos(t)
eq2=diff(y,t)==x-y+2*t
syst=[eq1, eq2]
C1,C2=var('C1,C2')
sol=desolve_system(syst, [x, y], [0, C1, C2])
show(sol)
sol_x(t,C1,C2)=sol[0].rhs()
show(sol_x)
reprx=plot(sol_x(t, 1, 1), t, -4, 4, color='yellow',ymin=-10,ymax=10)
sol_y(t,C1,C2)=sol[1].rhs()
show(sol_y)
repry=plot(sol_y(t, 1, 1), t, -4, 4, color='cyan',ymin=-10,ymax=10)
show(reprx+repry)
# Out:
# [x(t) == 3/40*(10*C1 + 10*C2 + 9)*e^(2*t) + 1/40*(10*C1 - 30*C2 - 19)*e^(-2*t) - 3/2*t - 1/5*cos(t) + 1/5*sin(t),
#  y(t) == 1/40*(10*C1 + 10*C2 + 9)*e^(2*t) - 1/40*(10*C1 - 30*C2 - 19)*e^(-2*t) + 1/2*t - 1/5*cos(t) - 1/2]
# (t, C1, C2) |--> 3/40*(10*C1 + 10*C2 + 9)*e^(2*t) + 1/40*(10*C1 - 30*C2 - 19)*e^(-2*t) - 3/2*t - 1/5*cos(t) + 1/5*sin(t)
# (t, C1, C2) |--> 1/40*(10*C1 + 10*C2 + 9)*e^(2*t) - 1/40*(10*C1 - 30*C2 - 19)*e^(-2*t) + 1/2*t - 1/5*cos(t) - 1/2
# Graphics object consisting of 2 graphics primitives

# %%
t=var('t')
x=function('x')(t)
y=function('y')(t)
z=function('z')(t)
eq1=diff(x,t)==x-2*y-2*z+e^(-t)
eq2=diff(y,t)==-2*x+y+2*z
eq3=diff(z,t)==2*x-y-3*z+e^(-t)
syst=[eq1, eq2, eq3]
C1,C2,C3=var('C1,C2,C3')
sol=desolve_system(syst, [x, y, z], [0, C1, C2, C3])
show(sol)
sol_x(t,C1,C2,C3)=sol[0].rhs()
show(sol_x)
reprx=plot(sol_x(t, 1, 2, -1), t, -4, 4, color='red',ymin=-10,ymax=10)
sol_y(t,C1,C2,C3)=sol[1].rhs()
show(sol_y)
repry=plot(sol_y(t, 1, 2, -1), t, -4, 4, color='cyan',ymin=-10,ymax=10)
sol_z(t,C1,C2,C3)=sol[2].rhs()
show(sol_z)
reprz=plot(sol_z(t, 1, 2, -1), t, -4, 4, color='blue',ymin=-10,ymax=10)
show(reprx+repry+reprz)
# Out:
# [x(t) == 1/3*sqrt(3)*(2*C1 - C2 - 2*C3)*sinh(sqrt(3)*t) - C2*cosh(sqrt(3)*t) + (C1 + C2)*e^(-t) + t*e^(-t),
#  y(t) == -1/3*sqrt(3)*(2*C1 - C2 - 2*C3)*sinh(sqrt(3)*t) + C2*cosh(sqrt(3)*t),
#  z(t) == sqrt(3)*(C1 - C3)*sinh(sqrt(3)*t) - (C1 + C2 - C3)*cosh(sqrt(3)*t) + (C1 + C2)*e^(-t) + t*e^(-t)]
# (t, C1, C2, C3) |--> 1/3*sqrt(3)*(2*C1 - C2 - 2*C3)*sinh(sqrt(3)*t) - C2*cosh(sqrt(3)*t) + (C1 + C2)*e^(-t) + t*e^(-t)
# (t, C1, C2, C3) |--> -1/3*sqrt(3)*(2*C1 - C2 - 2*C3)*sinh(sqrt(3)*t) + C2*cosh(sqrt(3)*t)
# (t, C1, C2, C3) |--> sqrt(3)*(C1 - C3)*sinh(sqrt(3)*t) - (C1 + C2 - C3)*cosh(sqrt(3)*t) + (C1 + C2)*e^(-t) + t*e^(-t)
# Graphics object consisting of 3 graphics primitives

# %%
t=var('t')
x=function('x')(t)
y=function('y')(t)
eq1=diff(x,t)==x+4*y
eq2=diff(y,t)==x+y
syst=[eq1, eq2]
sol=desolve_system(syst, [x, y], [0, 1, 2])
show(sol)
sol_x(t)=sol[0].rhs()
show(sol_x)
reprx=plot(sol_x(t), t, -4, 4, color='red',ymin=-10,ymax=10)
sol_y(t)=sol[1].rhs()
show(sol_y)
repry=plot(sol_y(t), t, -4, 4, color='blue',ymin=-10,ymax=10)
show(reprx+repry)
# Out:
# [x(t) == 5/2*e^(3*t) - 3/2*e^(-t), y(t) == 5/4*e^(3*t) + 3/4*e^(-t)]
# t |--> 5/2*e^(3*t) - 3/2*e^(-t)
# t |--> 5/4*e^(3*t) + 3/4*e^(-t)
# Graphics object consisting of 2 graphics primitives

# %%
t=var('t')
x=function('x')(t)
y=function('y')(t)
eq1=diff(x,t)==x-y+t-1
eq2=diff(y,t)==-2*x+4*y+cos(t)
syst=[eq1, eq2]
sol=desolve_system(syst, [x, y], [0, 0, 1])
show(sol)
sol_x(t)=sol[0].rhs()
show(sol_x)
reprx=plot(sol_x(t), t, -4, 4, color='red',ymin=-10,ymax=10)
sol_y(t)=sol[1].rhs()
show(sol_y)
repry=plot(sol_y(t), t, -4, 4, color='blue',ymin=-10,ymax=10)
show(reprx+repry)
# Out:
# [x(t) == -1/13*(10*sqrt(17)*sinh(1/2*sqrt(17)*t) - 33*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - 2*t - 1/26*cos(t) + 5/26*sin(t) - 5/2,
#  y(t) == -1/26*(3*sqrt(17)*sinh(1/2*sqrt(17)*t) - 71*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - t - 3/13*cos(t) + 2/13*sin(t) - 3/2]
# t |--> -1/13*(10*sqrt(17)*sinh(1/2*sqrt(17)*t) - 33*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - 2*t - 1/26*cos(t) + 5/26*sin(t) - 5/2
# t |--> -1/26*(3*sqrt(17)*sinh(1/2*sqrt(17)*t) - 71*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - t - 3/13*cos(t) + 2/13*sin(t) - 3/2
# Graphics object consisting of 2 graphics primitives

# %%
t=var('t')
x=function('x')(t)
y=function('y')(t)
eq1=diff(x,t)==x+2*y+e^(-t)
eq2=diff(y,t)==-2*x+y+1
syst=[eq1, eq2]
sol=desolve_system(syst, [x, y], [0, 0, 1])
show(sol)
sol_x(t)=sol[0].rhs()
show(sol_x)
reprx=plot(sol_x(t), t, -4, 4, color='red',ymin=-30,ymax=30)
sol_y(t)=sol[1].rhs()
show(sol_y)
repry=plot(sol_y(t), t, -4, 4, color='blue',ymin=-30,ymax=40)
show(reprx+repry)
# Out:
# [x(t) == -1/20*(3*cos(2*t) - 29*sin(2*t))*e^t - 1/4*e^(-t) + 2/5,
#  y(t) == 1/20*(29*cos(2*t) + 3*sin(2*t))*e^t - 1/4*e^(-t) - 1/5]
# t |--> -1/20*(3*cos(2*t) - 29*sin(2*t))*e^t - 1/4*e^(-t) + 2/5
# t |--> 1/20*(29*cos(2*t) + 3*sin(2*t))*e^t - 1/4*e^(-t) - 1/5
# Graphics object consisting of 2 graphics primitives

# %%
t=var('t')
x=function('x')(t)
y=function('y')(t)
z=function('z')(t)
eq1=diff(x,t)==-x+e*y+3*z+27*t^2
eq2=diff(y,t)==2*x-2*y-5*z+3*t
eq3=diff(z,t)==-2*x+3*y+6*z+3
syst=[eq1, eq2, eq3]
sol=desolve_system(syst, [x, y, z], [0, 50, -30, 26])
show(sol)
sol_x(t)=sol[0].rhs()
show(sol_x)
reprx=plot(sol_x(t), t, -12, 12, color='red',ymin=-200,ymax=200)
sol_y(t)=sol[1].rhs()
show(sol_y)
repry=plot(sol_y(t), t, -12, 12, color='cyan',ymin=-200,ymax=200)
sol_z(t)=sol[2].rhs()
show(sol_z)
reprz=plot(sol_z(t), t, -12, 12, color='blue',ymin=-200,ymax=200)
show(reprx+repry+reprz)
# Out:
# [x(t) == -2*(((120*e^5 - 308*e^4 - 750*e^3 + 2529*e^2 - 2484*e + 891)/(8*e^4 - 44*e^3 + 90*e^2 - 81*e + 27) - 2*(120*e^4 - 670*e^3 + 1251*e^2 - 1080*e + 378)/(8*e^4 - 44*e^3 + 90*e^2 - 81*e + 27))*sinh(t*sqrt(2*e - 2))/sqrt(2*e - 2) - 2*(120*e^4 - 670*e^3 + 1251*e^2 - 1080*e + 378)*cosh(t*sqrt(2*e - 2))/(8*e^4 - 44*e^3 + 90*e^2 - 81*e + 27))*e^t - 9/2*t*(4*e^2 + 27)/(4*e^2 - 12*e + 9) + 81*t^2/(2*e - 3) - 18*t*e^2/(4*e^2 - 12*e + 9) + (5*e - 9)*e^t/(e - 1) - 3*(40*e^3 - 204*e^2 + 162*e - 135)/(8*e^3 - 36*e^2 + 54*e - 27) - 243/2*t/(4*e^2 - 12*e + 9),
# ...
